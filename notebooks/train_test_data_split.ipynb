# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(42)

# %%
DATA_DIR = "data/"

# %%
data_path = DATA_DIR + 'Brunel_BdJPsiKs_MagU_30k.pkl'

# %%
seed_data = pd.read_pickle(data_path)

# %%
seed_data.head()
# Out:
#    has_MCParticle  is_downstream_reconstructible  has_MCParticle_not_electron  \
# 0            True                          False                         True
# 1            True                           True                         True
# 2            True                           True                         True
# 3            True                           True                        False
# 4            True                          False                         True
#
#    is_downstream_reconstructible_not_electron  is_true_seed  seed_chi2PerDoF  \
# 0                                       False         False         1.447929
# 1                                        True         False         0.354945
# 2                                        True          True         2.906524
# 3                                       False         False         3.234916
# 4                                       False         False         0.842265
#
# ...

# %%
new_data = seed_data[seed_data['has_MCParticle']&seed_data['has_MCParticle_not_electron']]

# %%
y_train = new_data['is_downstream_reconstructible'].astype(int)

# %%
len(y_train)
# Out:
# 1792768

# %%
good_track_no = counts = sum(y_train == 1)
ghost_track_no = counts = sum(y_train == 0)
print("good tracks %d" % good_track_no)
print("ghost track %d" % ghost_track_no)
ratio_ghost_to_good = float(ghost_track_no)/good_track_no
ratio_ghost_to_good = np.round(ratio_ghost_to_good, 3)
print("ratio ghost to good %f" % ratio_ghost_to_good)
# Out:
# good tracks 1151149
# ghost track 641619
# ratio ghost to good 0.557000

# %%
seed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2415200 entries, 0 to 2415199
# Data columns (total 16 columns):
# has_MCParticle                                bool
# is_downstream_reconstructible                 bool
# has_MCParticle_not_electron                   bool
# is_downstream_reconstructible_not_electron    bool
# is_true_seed                                  bool
# seed_chi2PerDoF                               float64
# seed_p                                        float64
# seed_pt                                       float64
# seed_nLHCbIDs                                 uint32
# seed_nbIT                                     uint32
# seed_nLayers                                  uint32
# seed_x                                        float64
# seed_y                                        float64
# seed_tx                                       float64
# seed_ty                                       float64
# seed_mva_value                                float64
# ...

# %%
seed_data.describe()
# Out:
#        seed_chi2PerDoF        seed_p       seed_pt  seed_nLHCbIDs  \
# count     2.415200e+06  2.415200e+06  2.415200e+06   2.415200e+06
# mean      1.871657e+00  2.138872e+04  1.730661e+03   1.792164e+01
# std       1.274678e+00  1.528150e+06  6.397556e+04   4.672918e+00
# min       1.030490e-03  1.121404e+03  2.736860e+00   8.000000e+00
# 25%       9.834252e-01  3.318111e+03  9.752144e+02   1.300000e+01
# 50%       1.494130e+00  6.400423e+03  1.153456e+03   1.900000e+01
# 75%       2.391722e+00  1.445767e+04  1.406610e+03   2.200000e+01
# max       8.999642e+00  1.741231e+09  5.879921e+07   3.400000e+01
#
#           seed_nbIT  seed_nLayers        seed_x        seed_y       seed_tx  \
# count  2.415200e+06  2.415200e+06  2.415200e+06  2.415200e+06  2.415200e+06
# mean   2.797962e+00  1.125978e+01  4.302253e-01 -4.526582e+00 -2.401685e-03
# std    4.762586e+00  1.028624e+00  7.095528e+02  5.222606e+02  3.068898e-01
# ...

# %%
seed_data.hist(bins=50, figsize=(15,15))
plt.savefig("plots/histogram_plots_original_data")

# %%
np.random.seed(42)
seed_data_w_id = seed_data.reset_index()
seed_data_w_id.head()
# Out:
#    index  has_MCParticle  is_downstream_reconstructible  \
# 0      0            True                          False
# 1      1            True                           True
# 2      2            True                           True
# 3      3            True                           True
# 4      4            True                          False
#
#    has_MCParticle_not_electron  is_downstream_reconstructible_not_electron  \
# 0                         True                                       False
# 1                         True                                        True
# 2                         True                                        True
# 3                        False                                       False
# 4                         True                                       False
#
#    is_true_seed  seed_chi2PerDoF        seed_p      seed_pt  seed_nLHCbIDs  \
# 0         False         1.447929   1849.101146  1083.522737             27
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(seed_data_w_id, test_size=0.2, random_state=42)
test_set.head()
# Out:
#            index  has_MCParticle  is_downstream_reconstructible  \
# 623302    623302            True                          False
# 199913    199913            True                           True
# 1726917  1726917            True                           True
# 994153    994153            True                          False
# 300320    300320            True                          False
#
#          has_MCParticle_not_electron  \
# 623302                         False
# 199913                          True
# 1726917                        False
# 994153                          True
# 300320                          True
#
#          is_downstream_reconstructible_not_electron  is_true_seed  \
# 623302                                        False         False
# 199913                                         True         False
# 1726917                                       False         False
# 994153                                        False         False
# ...

# %%
train_set.drop(['index'], axis=1).hist(bins=50, figsize=(15,15))
plt.savefig("plots/histogram_plots_train_set")

# %%
test_set.drop(['index'], axis=1).hist(bins=50, figsize=(15,15))
plt.savefig("plots/histogram_plots_test_set")

# %%
# test_set.to_pickle(DATA_DIR + "test_data.pkl")
# train_set.to_pickle(DATA_DIR + "train_data.pkl")
